# %%
import pandas as pd 
import matplotlib as plt

df = pd.read_csv("Akinator1.csv")

# %% [markdown]
# 1)Création d'une fonction pour récuperer les colonnes intéressantes pour mon nouveau dataFrame \
# 2)Renommer les colonnes \
# 3)Convertir h/f par 1 / 0 et supprimer l'ancienne colonne

# %%
def select_columns(data_frame, column_names):
    new_frame = data_frame.loc[:, column_names]
    return new_frame.copy()
selected_columns = ['Nom','Thé ou Café','Fumeur',
                    'H / F', 'Gaming ?',
                    'Echecs', 'Allergies ?',
                    'Mac ou PC ?', 'Des enfants?',
                    'Tatouage? ', 'Sucré ou salé?',
                    ' Jour ou Nuit ', 'Taille (cm)', 'Taille de pied' ]

data = select_columns(df, selected_columns)
data.rename(columns={"Thé ou Café": "Tea_coffee", "H / F" : "sex" }, inplace = True)
data.insert(3, column = "sexe", value = data["sex"].apply(lambda x: 1 if x == "h" else 0))
data.drop("sex", axis= 1, inplace = True)

dummies = pd.get_dummies(data["sexe"])
data = data.join(dummies)
data.rename(columns={0: "Hommes", 1 : "Femmes" }, inplace = True)
data["sexe"] = data["sexe"].apply(lambda x: 'Hommes' if x == 1 else 'Femmes')

# %%
c = ['green', 'orange', 'red']
ax = data["Echecs"].value_counts().plot(kind = "bar", rot=0, figsize = (8, 8), color = c) # if Pie =>> autopct='%.1f%%')
ax.set_title("Chess Player",color='black')
ax.legend(bbox_to_anchor=(1.0, 1.0))
ax.plot()
# Out:
# []

# %%
ax = data["sexe"].value_counts().plot(kind = "pie", figsize = (8, 8), autopct='%.1f%%', )
ax.set_title("Genre",color='black')
ax.legend(bbox_to_anchor=(1.0, 1.0))
ax.plot()
# Out:
# []

# %%
data
# Out:
#           Nom   Tea_coffee       Fumeur    sexe Gaming ?       Echecs  \
# 0    Serafini          Thé          non  Hommes      non  occasionnel
# 1      Rogeon         Café          oui  Femmes      non  occasionnel
# 2        Nowe         Café          oui  Hommes      non  occasionnel
# 3     Hoareau         Café          non  Hommes      oui          oui
# 4       Lizot  Café et Thé          non  Femmes      oui          oui
# 5    Langella          Thé          oui  Hommes      oui  occasionnel
# 6    Delauney          Thé          non  Femmes      oui          non
# 7      Nathou          Thé          non  Femmes      oui          non
# 8        Wilk         Café  occasionnel  Hommes      oui          oui
# 9      Sqalli         Café  occasionnel  Hommes      non          non
# 10    Meunier         Café          oui  Hommes      non  occasionnel
# 11   Andurand         Café          oui  Hommes      non          non
# 12    Goubert        Café           oui  Hommes      oui          non
# 13     Asngar  Café et Thé          non  Femmes      non  occasionnel
# 14  Baffoigne  Café et Thé          non  Hommes      oui          non
# 15     Mugica         Café          non  Hommes      oui          non
# 16   Asatrian          Thé          non  Femmes      non          non
# 17       Rose  Café et Thé          non  Femmes      oui  occasionnel
# 18  Pouzoulet         Café          non  Hommes      non          oui
# 19     Gnambe         Café          non  Hommes      oui          oui
# 20  Odekerken         Café          non  Hommes      non          non
# 21    Gueddar  Café et Thé          non  Hommes      non          non
#
#    Allergies ? Mac ou PC ? Des enfants? Tatouage?  Sucré ou salé?  \
# 0     soleil ☀         Mac          oui        non           salé
# 1          oui          PC          non        oui           salé
# 2          non          PC          non        non           salé
# 3          non          PC          non        non           salé
# 4         soja         Mac          non        oui           salé
# 5          non          PC          non        non           salé
# 6          non          PC          non        oui          sucré
# 7          non         Mac          oui        oui           salé
# 8     gluten 🥖          PC          non        non           salé
# 9          non         Mac          non        non           salé
# 10         non          PC          non        oui          sucré
# 11         non          PC          non        oui          sucré
# 12         non          PC          non        non           Salé
# 13         oui          PC          non        non          sucré
# 14         non          PC          non        non           both
# 15         non          PC          non        non           salé
# 16         oui          PC          non        non           salé
# 17         oui          PC          oui        non           Both
# 18         non          PC          oui        oui           salé
# 19         oui         Mac          oui        oui           Salé
# 20         non         Mac          non        non           salé
# 21         non          PC          oui        non     sucré/salé
#
#     Jour ou Nuit   Taille (cm)  Taille de pied  Hommes  Femmes
# 0            nuit        190.0            46.0       0       1
# 1            jour        167.5            38.5       1       0
# 2            jour        188.0            46.0       0       1
# 3            jour        175.0            43.0       0       1
# 4            nuit        158.5            37.5       1       0
# 5            nuit        171.0            41.0       0       1
# 6            jour        161.0            39.0       1       0
# 7            nuit        151.0            36.0       1       0
# 8            nuit        181.0            44.0       0       1
# 9            jour        174.0            42.5       0       1
# 10           jour        172.0            41.0       0       1
# 11           jour        180.0            43.0       0       1
# 12           nuit        230.0            48.0       0       1
# 13           nuit        176.0            42.0       1       0
# 14           nuit        161.0            41.0       0       1
# 15           Nuit        186.0            45.0       0       1
# 16           jour         91.0            76.0       1       0
# 17           nuit        158.0            36.0       1       0
# 18           jour        180.0            42.0       0       1
# 19           Nuit        187.0            44.5       0       1
# 20           Jour        184.0            42.5       0       1
# 21           Jour          NaN             NaN       0       1

# %%
ax = data[["Echecs", "sexe"]].value_counts().plot(kind = "pie", figsize = (8, 8), autopct='%.1f%%', )
ax.set_title("Genre",color='black')
ax.legend(bbox_to_anchor=(1.0, 1.0))
ax.plot()
# Out:
# []

# %%
ax = data.groupby("Echecs")["sexe"].value_counts().plot(kind = "bar", rot = 50, figsize = (8, 8))
ax.set_title("Genre",color='black')
ax.legend(bbox_to_anchor=(1.0, 1.0))
ax.plot()
# Out:
# []

# %%
ax = data[["sexe", "Jour ou Nuit"]].value_counts().plot(kind = "bar", figsize = (8, 8)) #,autopct='%.1f%%', )
ax.set_title("Genre",color='black')
ax.legend(bbox_to_anchor=(1.0, 1.0))
ax.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [198], line 1
# ----> 1 ax = data[["sexe", "Jour ou Nuit"]].value_counts().plot(kind = "bar", figsize = (8, 8)) #,autopct='%.1f%%', )
#       2 ax.set_title("Genre",color='black')
#       3 ax.legend(bbox_to_anchor=(1.0, 1.0))
#
# File ~/.pyenv/versions/simplon/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/simplon/lib/python3.8/site-packages/pandas/core/indexes/base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/simplon/lib/python3.8/site-packages/pandas/core/indexes/base.py:5859, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Jour ou Nuit'] not in index"

# %%
plt.scatter(data["Taille de pied"], data["Taille en (cm)"], c = black)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/simplon/lib/python3.8/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/.pyenv/versions/simplon/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/simplon/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Taille en (cm)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [200], line 1
# ----> 1 plt.scatter(data["Taille de pied"], data["Taille en (cm)"], c = black)
#
# File ~/.pyenv/versions/simplon/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.pyenv/versions/simplon/lib/python3.8/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Taille en (cm)'

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['Oui', 'Non', 'Pt']
counts = [15, 6, 1]

ax.bar(fruits, counts)

ax.set_ylabel('Fumeur')
ax.set_title('Titre')


plt.show()

# %%
data.groupby('sexe')['Fumeur'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot: ylabel='Fumeur'>

# %%
data
# Out:
#           Nom   Tea_coffee       Fumeur    sexe Gaming ?       Echecs  \
# 0    Serafini          Thé          non  Hommes      non  occasionnel
# 1      Rogeon         Café          oui  Femmes      non  occasionnel
# 2        Nowe         Café          oui  Hommes      non  occasionnel
# 3     Hoareau         Café          non  Hommes      oui          oui
# 4       Lizot  Café et Thé          non  Femmes      oui          oui
# 5    Langella          Thé          oui  Hommes      oui  occasionnel
# 6    Delauney          Thé          non  Femmes      oui          non
# 7      Nathou          Thé          non  Femmes      oui          non
# 8        Wilk         Café  occasionnel  Hommes      oui          oui
# 9      Sqalli         Café  occasionnel  Hommes      non          non
# 10    Meunier         Café          oui  Hommes      non  occasionnel
# 11   Andurand         Café          oui  Hommes      non          non
# 12    Goubert        Café           oui  Hommes      oui          non
# 13     Asngar  Café et Thé          non  Femmes      non  occasionnel
# 14  Baffoigne  Café et Thé          non  Hommes      oui          non
# 15     Mugica         Café          non  Hommes      oui          non
# 16   Asatrian          Thé          non  Femmes      non          non
# 17       Rose  Café et Thé          non  Femmes      oui  occasionnel
# 18  Pouzoulet         Café          non  Hommes      non          oui
# 19     Gnambe         Café          non  Hommes      oui          oui
# 20  Odekerken         Café          non  Hommes      non          non
# 21    Gueddar  Café et Thé          non  Hommes      non          non
#
#    Allergies ? Mac ou PC ? Des enfants? Tatouage?  Sucré ou salé?  \
# 0     soleil ☀         Mac          oui        non           salé
# 1          oui          PC          non        oui           salé
# 2          non          PC          non        non           salé
# 3          non          PC          non        non           salé
# 4         soja         Mac          non        oui           salé
# 5          non          PC          non        non           salé
# 6          non          PC          non        oui          sucré
# 7          non         Mac          oui        oui           salé
# 8     gluten 🥖          PC          non        non           salé
# 9          non         Mac          non        non           salé
# 10         non          PC          non        oui          sucré
# 11         non          PC          non        oui          sucré
# 12         non          PC          non        non           Salé
# 13         oui          PC          non        non          sucré
# 14         non          PC          non        non           both
# 15         non          PC          non        non           salé
# 16         oui          PC          non        non           salé
# 17         oui          PC          oui        non           Both
# 18         non          PC          oui        oui           salé
# 19         oui         Mac          oui        oui           Salé
# 20         non         Mac          non        non           salé
# 21         non          PC          oui        non     sucré/salé
#
#     Jour ou Nuit   Taille (cm)  Taille de pied  Hommes  Femmes
# 0            nuit        190.0            46.0       0       1
# 1            jour        167.5            38.5       1       0
# 2            jour        188.0            46.0       0       1
# 3            jour        175.0            43.0       0       1
# 4            nuit        158.5            37.5       1       0
# 5            nuit        171.0            41.0       0       1
# 6            jour        161.0            39.0       1       0
# 7            nuit        151.0            36.0       1       0
# 8            nuit        181.0            44.0       0       1
# 9            jour        174.0            42.5       0       1
# 10           jour        172.0            41.0       0       1
# 11           jour        180.0            43.0       0       1
# 12           nuit        230.0            48.0       0       1
# 13           nuit        176.0            42.0       1       0
# 14           nuit        161.0            41.0       0       1
# 15           Nuit        186.0            45.0       0       1
# 16           jour         91.0            76.0       1       0
# 17           nuit        158.0            36.0       1       0
# 18           jour        180.0            42.0       0       1
# 19           Nuit        187.0            44.5       0       1
# 20           Jour        184.0            42.5       0       1
# 21           Jour          NaN             NaN       0       1
