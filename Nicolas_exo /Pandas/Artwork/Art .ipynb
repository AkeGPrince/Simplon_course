# %% [markdown]
# # Consignes
# Question 1 : Please review the quality of the data, describe the data you are working on and present any issues
# 	- To do for artworks.csv
#
# Question 2 : Draw a graph that would help us to understand more clearly the dataset
#
# Question 3 : Let suppose you are a data scientist. You might consider cluster this dataset to get for example different clusters.
# Which relevant transformations / data cleaning operations would you do before ?
#
# Indications:
# 1. Are all the columns useful ?
# 2. What you are going to do on elements from artists table is called feature engineering:
# 	- get actual age or death age
# 	- is the artist alived : create a new column and sets 1 if it'is alived otherwise 0.
# 	- if possible, calculate the volumes of the artwork
# 	- Count number of elements inside 'Name_caller' and print the result inside a new column
#
#
# 3. On artworks table:
# 	- Acquisition date : transformed in another format
# 	- delete lines/columns ?
# 	- fill missing info ?
#
#
# Bonus:
# - Draw 2 easy other graphs that are useful to understand the dataset
# - Is it possible to create a unify dataset, from the two files mentioned above ? If possible, do it and create a .csv file
# - Clean artists.csv
#
# NB:
# You have to use the following methods:
# .describe()
# .unique()
# .fillna()
# .dropna()
# .apply()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("artworks.csv")

# %%
df.count() / df.shape[0] * 100
# Out:
# Artwork ID            100.000000
# Title                  99.960080
# Artist ID              98.879182
# Name                   98.879182
# Date                   98.225116
# Medium                 90.849979
# Dimensions             91.200043
# Acquisition Date       95.806145
# Credit                 97.643211
# Catalogue             100.000000
# Department            100.000000
# Classification        100.000000
# Object Number         100.000000
# Diameter (cm)           1.073989
# Circumference (cm)      0.007677
# Height (cm)            85.898420
# Length (cm)             0.565015
# Width (cm)             85.215182
# Depth (cm)              8.784603
# Weight (kg)             0.228770
# Duration (s)            2.367536
# dtype: float64

# %%
df[df['Dimensions'].isnull()]
# Out:
#         Artwork ID                                              Title  \
# 77             102                                      Misc. objects
# 185            241  American System-Built Houses for The Richards ...
# 239            297  Sixth Street House project, Santa Monica, Cali...
# 361            433                Airplane Hangar Project (Roof plan)
# 399            471  New York Tower project, New York, NY (Tower fa...
# ...            ...                                                ...
# 130256      217982                                        Study No. 3
# 130257      217983                                        Seul/NY/MAX
# 130258      217984   Fluxus-Manifestatie in en Rond Kunsthandel Monet
# 130259      217985                             Fluxphone Compositions
# 130260      217986                                       Unidentified
#
#               Artist ID                                            Name  \
# 77                 7166                        Ludwig Mies van der Rohe
# 185                6459                              Frank Lloyd Wright
# 239         8218, 22884                         Thom Mayne, Andrew Zago
# 361                6201                                Konrad Wachsmann
# 399     632, 8822, 8823  Ricardo Bofill, Gregory Baird, Rogelio Jimenez
# ...                 ...                                             ...
# 130256             4469                                   Nam June Paik
# 130257             4469                                   Nam June Paik
# 130258              NaN                                             NaN
# 130259            67695                                       Ely Ramen
# 130260              NaN                                             NaN
#
#                       Date                              Medium Dimensions  \
# 77                    n.d.                                 NaN        NaN
# 185                1915-17                          Lithograph        NaN
# 239     .1-3 1987; .4 1990  Serigraph with metal foil on paper        NaN
# 361                   1963                          Lithograph        NaN
# 399                   1985           Ink and airbrush on paper        NaN
# ...                    ...                                 ...        ...
# 130256                 NaN                                 VHS        NaN
# 130257                 NaN                                 VHS        NaN
# 130258                1962                                 VHS        NaN
# 130259                1969                            Cassette        NaN
# 130260                 NaN                            Cassette        NaN
#
#        Acquisition Date                                             Credit  \
# 77           1980-01-08  Mies van der Rohe Archive, gift of Ludwig Glaeser
# 185          1993-05-04  Gift of David Rockefeller, Jr. Fund, Ira Howar...
# 239          1999-06-30                                  Given anonymously
# 361          1969-04-24                            Gift of Ivan Chermayeff
# 399          1985-11-18      Gift of Ricardo Bofill Taller de Arquitectura
# ...                 ...                                                ...
# 130256       2008-10-08  The Gilbert and Lila Silverman Fluxus Collecti...
# 130257       2008-10-08  The Gilbert and Lila Silverman Fluxus Collecti...
# 130258       2008-10-08  The Gilbert and Lila Silverman Fluxus Collecti...
# 130259       2008-10-08  The Gilbert and Lila Silverman Fluxus Collecti...
# 130260       2008-10-08  The Gilbert and Lila Silverman Fluxus Collecti...
#
#        Catalogue  ...             Classification  Object Number Diameter (cm)  \
# 77             N  ...  Mies van der Rohe Archive  29.1980.1-248           NaN
# 185            N  ...               Architecture  155.1993.1-36           NaN
# 239            N  ...               Architecture   272.1999.1-4           NaN
# 361            Y  ...               Architecture       375.1969           NaN
# 399            Y  ...               Architecture       385.1985           NaN
# ...          ...  ...                        ...            ...           ...
# 130256         N  ...                      Media         FC5037           NaN
# 130257         N  ...                      Media         FC5038           NaN
# 130258         N  ...                      Media         FC5039           NaN
# 130259         N  ...                      Media         FC5040           NaN
# 130260         N  ...                      Media         FC5041           NaN
#
#         Circumference (cm)  Height (cm)  Length (cm)  Width (cm)  Depth (cm)  \
# 77                     NaN          NaN          NaN         NaN         NaN
# 185                    NaN          NaN          NaN         NaN         NaN
# 239                    NaN          NaN          NaN         NaN         NaN
# 361                    NaN          NaN          NaN         NaN         NaN
# 399                    NaN          NaN          NaN         NaN         NaN
# ...                    ...          ...          ...         ...         ...
# 130256                 NaN          0.0          NaN         0.0         0.0
# 130257                 NaN          0.0          NaN         0.0         0.0
# 130258                 NaN          0.0          NaN         0.0         0.0
# 130259                 NaN          0.0          NaN         0.0         0.0
# 130260                 NaN          0.0          NaN         0.0         0.0
#
#         Weight (kg)  Duration (s)
# 77              NaN           NaN
# 185             NaN           NaN
# 239             NaN           NaN
# 361             NaN           NaN
# 399             NaN           NaN
# ...             ...           ...
# 130256          NaN           NaN
# 130257          NaN           NaN
# 130258          NaN           NaN
# 130259          NaN           NaN
# 130260          NaN           NaN
#
# [11463 rows x 21 columns]

# %%
#df['Acquisition_year'] = pd.DatetimeIndex(df['Acquisition Date']).year
df.loc[[129661],['Acquisition Date']] = float('NaN')

# %%
df['Acquisition_year'] = pd.DatetimeIndex(df['Acquisition Date']).year

# %%
df['Acquisition_year'].fillna(0, inplace = True)

# %%
df['acquisition_year'] = pd.DatetimeIndex(df['Acquisition Date']).year

# %%
df['acquisition_year']
# Out:
# 0         1996.0
# 1         1995.0
# 2         1997.0
# 3         1995.0
# 4         1997.0
#            ...
# 130257    2008.0
# 130258    2008.0
# 130259    2008.0
# 130260    2008.0
# 130261    2008.0
# Name: acquisition_year, Length: 130262, dtype: float64

# %%
df[df['Acquisition_year'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Artwork ID, Title, Artist ID, Name, Date, Medium, Dimensions, Acquisition Date, Credit, Catalogue, Department, Classification, Object Number, Diameter (cm), Circumference (cm), Height (cm), Length (cm), Width (cm), Depth (cm), Weight (kg), Duration (s), Acquisition_year, acquisition_year]
# Index: []
#
# [0 rows x 23 columns]

# %%
df['Acquisition_year'] = df['Acquisition_year'].astype(int)

# %%
df['Acquisition_year']
# Out:
# 0         1996
# 1         1995
# 2         1997
# 3         1995
# 4         1997
#           ...
# 130257    2008
# 130258    2008
# 130259    2008
# 130260    2008
# 130261    2008
# Name: Acquisition_year, Length: 130262, dtype: int64

# %%
df_test = df_test.sort_values(by=['Acquisition_year'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 df_test = df_test.sort_values(by=['Acquisition_year'])
#
# NameError: name 'df_test' is not defined

# %%
df_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 df_test
#
# NameError: name 'df_test' is not defined

# %%
df_test['Acquisition_year'].value_counts().plot(kind='bar',
                           figsize=[20, 8], title="Nombre d'acquisitions par année",
                           rot=45, legend=True, ylabel="Nombre d'acquisitions",
                           xlabel="Year", fontsize='large', sort_columns= True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 df_test['Acquisition_year'].value_counts().plot(kind='bar',
#       2                            figsize=[20, 8], title="Nombre d'acquisitions par année",
#       3                            rot=45, legend=True, ylabel="Nombre d'acquisitions",
#       4                            xlabel="Year", fontsize='large', sort_columns= True)
#
# NameError: name 'df_test' is not defined

# %%
df_test['Acquisition_year'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 df_test['Acquisition_year'].value_counts()
#
# NameError: name 'df_test' is not defined

# %%
df_test['Acquisition_year'].value_counts().sort_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 df_test['Acquisition_year'].value_counts().sort_values()
#
# NameError: name 'df_test' is not defined
